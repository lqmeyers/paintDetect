# %% [markdown]
# ## A notebook that runs UNet prediction in batches
#
# by only loading the model once to the gpu prediction is much faster

# %%
#import packages

import os
from datetime import datetime

import numpy as np
import os 
import argparse
import logging

import sys

import numpy as np
import torch
import torch.nn.functional as F
from PIL import Image



sys.path.insert(0,"./Pytorch-UNet/")
from utils.data_loading import BasicDataset
from unet import UNet
from utils.utils import plot_img_and_mask

# %%
# add relevant functions:

def predict_img(net,
                full_img,
                device,
                scale_factor=1,
                out_threshold=0.5):
    net.eval()
    img = torch.from_numpy(BasicDataset.preprocess(None, full_img, scale_factor, is_mask=False))
    img = img.unsqueeze(0)
    img = img.to(device=device, dtype=torch.float32)

    with torch.no_grad():
        output = net(img).cpu()
        output = F.interpolate(output, (full_img.size[1], full_img.size[0]), mode='bilinear')
        if net.n_classes > 1:
            mask = output.argmax(dim=1)
        else:
            mask = torch.sigmoid(output) > out_threshold

    return mask[0].long().squeeze().numpy()



def mask_to_image(mask: np.ndarray, mask_values):
    if isinstance(mask_values[0], list):
        out = np.zeros((mask.shape[-2], mask.shape[-1], len(mask_values[0])), dtype=np.uint8)
    elif mask_values == [0, 1]:
        out = np.zeros((mask.shape[-2], mask.shape[-1]), dtype=bool)
    else:
        out = np.zeros((mask.shape[-2], mask.shape[-1]), dtype=np.uint8)

    if mask.ndim == 3:
        mask = np.argmax(mask, axis=0)

    for i, v in enumerate(mask_values):
        out[mask == i] = v

    return Image.fromarray(out)

# %%
#initialize cuda 

import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU with index 1

# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    # Get the default CUDA device
    device = torch.device("cuda")

    # Query the available memory
    total_memory = torch.cuda.get_device_properties(device).total_memory
    allocated_memory = torch.cuda.memory_allocated(device)
    free_memory = total_memory - allocated_memory

    print(f"Total GPU Memory: {total_memory / 1024**2:.2f} MB")
    print(f"Allocated GPU Memory: {allocated_memory / 1024**2:.2f} MB")
    print(f"Free GPU Memory: {free_memory / 1024**2:.2f} MB")
else:
    print("CUDA is not available.")
# Out:
# Total GPU Memory: 24163.25 MB
# Allocated GPU Memory: 0.00 MB
# Free GPU Memory: 24163.25 MB

# %% [markdown]
# Specify input paramaters

# %%
image_dir = '/home/lmeyers/paintDetect/images/testing/'
model = '/home/lmeyers/paintDetect/wandb/run-20230526_003438-r4vajhjg/files/20230526_004722_model.pth'

# %% [markdown]
# The below code will create a new timestamped directory in the mask folder where predictions will be saved.
# It wil then load the model to the gpu and call each file in the image_dir and save with a .pred.jpg

# %%
current_date = datetime.now().strftime("%Y-%m-%d-%H:%M:%S")
directory_name = f"/home/lmeyers/paintDetect/data/thorax_only_masks/predict_{current_date}"
os.mkdir(directory_name)

#image_dir = "/home/lmeyers/paintDetect/images/testing/"


in_files = []
out_files = []

dir_list = os.walk(image_dir)
for root, dirs, files in dir_list:
    for f in files: 
        #print(root+f)
        in_files.append(root+f)
        out_files.append(f"/home/lmeyers/paintDetect/masks/predict_{current_date}/"+f[:-4]+'.Thorax.pred.jpg')


logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')


#model = '/home/lmeyers/paintDetect/wandb/latest-run/files/20230525_113551_model.pth'

net = UNet(n_channels=3, n_classes=2, bilinear=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
logging.info(f'Loading model {model}')
logging.info(f'Using device {device}')

net.to(device=device)
state_dict = torch.load(model, map_location=device)
mask_values = state_dict.pop('mask_values', [0, 1])
net.load_state_dict(state_dict)

logging.info('Model loaded!')

for i, filename in enumerate(in_files):
    logging.info(f'Predicting image {filename} ...')
    img = Image.open(filename)

    mask = predict_img(net=net,
                        full_img=img,
                        scale_factor=1,
                        out_threshold=.5,
                        device=device)

   
    out_filename = out_files[i]
    result = mask_to_image(mask, mask_values)
    result.save(out_filename)
    logging.info(f'Mask saved to {out_filename}')
# Out:
# INFO: Loading model /home/lmeyers/paintDetect/wandb/latest-run/files/20230525_113551_model.pth
# INFO: Using device cuda
# INFO: Model loaded!
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f13x2022_06_28.mp4.track000076.frame002641.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f13x2022_06_28.mp4.track000076.frame002641.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f2x2022_06_22.mp4.track000022.frame004129.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f2x2022_06_22.mp4.track000022.frame004129.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f08x2022_06_28.mp4.track000082.frame001515.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f08x2022_06_28.mp4.track000082.frame001515.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f10x2022_06_28.mp4.track000162.frame003997.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f10x2022_06_28.mp4.track000162.frame003997.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f08x2022_06_28.mp4.track000023.frame000404.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f08x2022_06_28.mp4.track000023.frame000404.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f06x2022_06_28.mp4.track000306.frame004886.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f06x2022_06_28.mp4.track000306.frame004886.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f22x2022_06_28.mp4.track000014.frame000541.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f22x2022_06_28.mp4.track000014.frame000541.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f6.3x2022_06_20.mp4.track000211.frame008645.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f6.3x2022_06_20.mp4.track000211.frame008645.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f09x2022_06_28.mp4.track000358.frame007107.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f09x2022_06_28.mp4.track000358.frame007107.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f13x2022_06_28.mp4.track000091.frame003218.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f13x2022_06_28.mp4.track000091.frame003218.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f08x2022_06_28.mp4.track000097.frame002154.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f08x2022_06_28.mp4.track000097.frame002154.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f6.3x2022_06_20.mp4.track000401.frame013679.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f6.3x2022_06_20.mp4.track000401.frame013679.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f09x2022_06_28.mp4.track000317.frame005743.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f09x2022_06_28.mp4.track000317.frame005743.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f6.3x2022_06_20.mp4.track000051.frame003132.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f6.3x2022_06_20.mp4.track000051.frame003132.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f19x2022_06_28.mp4.track000067.frame002560.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f19x2022_06_28.mp4.track000067.frame002560.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f09x2022_06_28.mp4.track000153.frame003162.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f09x2022_06_28.mp4.track000153.frame003162.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f06x2022_06_28.mp4.track000405.frame009773.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f06x2022_06_28.mp4.track000405.frame009773.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f3.1x2022_06_22.mp4.track000093.frame007395.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f3.1x2022_06_22.mp4.track000093.frame007395.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f09x2022_06_28.mp4.track000177.frame004381.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f09x2022_06_28.mp4.track000177.frame004381.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f15x2022_06_28.mp4.track000391.frame008134.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f15x2022_06_28.mp4.track000391.frame008134.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f2x2022_07_22.mp4.track000042.frame003450.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f2x2022_07_22.mp4.track000042.frame003450.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f3x2022_07_15.mp4.track000382.frame023662.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f3x2022_07_15.mp4.track000382.frame023662.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f3x2022_07_22.mp4.track000181.frame011176.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f3x2022_07_22.mp4.track000181.frame011176.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f22x2022_06_28.mp4.track000064.frame004998.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f22x2022_06_28.mp4.track000064.frame004998.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f09x2022_06_28.mp4.track000392.frame007378.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f09x2022_06_28.mp4.track000392.frame007378.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f1.1x2022_06_22.mp4.track000051.frame005260.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f1.1x2022_06_22.mp4.track000051.frame005260.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f15x2022_06_28.mp4.track000094.frame002076.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f15x2022_06_28.mp4.track000094.frame002076.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f6.2x2022_06_20.mp4.track000103.frame006098.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f6.2x2022_06_20.mp4.track000103.frame006098.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f09x2022_06_28.mp4.track000213.frame004190.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f09x2022_06_28.mp4.track000213.frame004190.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f13x2022_06_28.mp4.track000089.frame003021.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f13x2022_06_28.mp4.track000089.frame003021.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f06x2022_06_28.mp4.track000344.frame005720.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f06x2022_06_28.mp4.track000344.frame005720.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f17x2022_06_28.mp4.track000186.frame005217.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f17x2022_06_28.mp4.track000186.frame005217.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f5x2022_06_20.mp4.track000048.frame007552.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f5x2022_06_20.mp4.track000048.frame007552.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f13x2022_06_28.mp4.track000164.frame005619.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f13x2022_06_28.mp4.track000164.frame005619.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f06x2022_06_28.mp4.track000115.frame001572.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f06x2022_06_28.mp4.track000115.frame001572.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f17x2022_06_28.mp4.track000119.frame002489.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f17x2022_06_28.mp4.track000119.frame002489.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f3.2x2022_06_22.mp4.track000016.frame001551.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f3.2x2022_06_22.mp4.track000016.frame001551.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f17x2022_06_28.mp4.track000248.frame007250.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f17x2022_06_28.mp4.track000248.frame007250.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f10x2022_06_28.mp4.track000159.frame003861.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f10x2022_06_28.mp4.track000159.frame003861.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f17x2022_06_28.mp4.track000010.frame000706.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f17x2022_06_28.mp4.track000010.frame000706.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f19x2022_06_28.mp4.track000000.frame000041.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f19x2022_06_28.mp4.track000000.frame000041.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f21x2022_06_28.mp4.track000002.frame000011.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f21x2022_06_28.mp4.track000002.frame000011.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f06x2022_06_28.mp4.track000401.frame009373.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f06x2022_06_28.mp4.track000401.frame009373.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f10x2022_06_28.mp4.track000241.frame005264.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f10x2022_06_28.mp4.track000241.frame005264.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f7x2022_06_20.mp4.track000001.frame000321.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f7x2022_06_20.mp4.track000001.frame000321.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f21x2022_06_28.mp4.track000008.frame000398.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f21x2022_06_28.mp4.track000008.frame000398.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f3.2x2022_06_22.mp4.track000091.frame008154.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f3.2x2022_06_22.mp4.track000091.frame008154.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f21x2022_06_28.mp4.track000028.frame002113.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f21x2022_06_28.mp4.track000028.frame002113.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f15x2022_06_28.mp4.track000130.frame003418.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f15x2022_06_28.mp4.track000130.frame003418.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f7x2022_06_20.mp4.track000063.frame000967.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f7x2022_06_20.mp4.track000063.frame000967.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f21x2022_06_28.mp4.track000026.frame002984.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f21x2022_06_28.mp4.track000026.frame002984.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f06x2022_06_28.mp4.track000401.frame009363.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f06x2022_06_28.mp4.track000401.frame009363.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f13x2022_06_28.mp4.track000139.frame005261.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f13x2022_06_28.mp4.track000139.frame005261.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/filesortf7x2022_06_20.mp4.track000051.frame000947.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/filesortf7x2022_06_20.mp4.track000051.frame000947.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f3.1x2022_06_22.mp4.track000055.frame004944.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f3.1x2022_06_22.mp4.track000055.frame004944.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f4x2022_06_22.mp4.track000002.frame000900.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f4x2022_06_22.mp4.track000002.frame000900.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f06x2022_06_28.mp4.track000381.frame007837.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f06x2022_06_28.mp4.track000381.frame007837.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f5x2022_06_20.mp4.track000052.frame008426.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f5x2022_06_20.mp4.track000052.frame008426.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f21x2022_06_28.mp4.track000004.frame000197.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f21x2022_06_28.mp4.track000004.frame000197.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f15x2022_06_28.mp4.track000017.frame000574.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f15x2022_06_28.mp4.track000017.frame000574.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f19x2022_06_28.mp4.track000142.frame005399.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f19x2022_06_28.mp4.track000142.frame005399.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f08x2022_06_28.mp4.track000066.frame001176.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f08x2022_06_28.mp4.track000066.frame001176.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f13x2022_06_28.mp4.track000054.frame001458.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f13x2022_06_28.mp4.track000054.frame001458.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f7x2022_06_20.mp4.track000018.frame000241.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f7x2022_06_20.mp4.track000018.frame000241.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f6.2x2022_06_20.mp4.track000075.frame004534.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f6.2x2022_06_20.mp4.track000075.frame004534.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f17x2022_06_28.mp4.track000206.frame006589.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f17x2022_06_28.mp4.track000206.frame006589.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f1.2x2022_06_22.mp4.track000004.frame001173.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f1.2x2022_06_22.mp4.track000004.frame001173.pred.jpg
# INFO: Predicting image /home/lmeyers/paintDetect/images/testing/f09x2022_06_28.mp4.track000176.frame005081.jpg ...
# INFO: Mask saved to /home/lmeyers/paintDetect/masks/predict_2023-05-25-12:02:04/f09x2022_06_28.mp4.track000176.frame005081.pred.jpg

# %%
##predict on single image to test parameters:

#imports 
from PIL import Image
from matplotlib import pyplot as plt

#specify file to test prediction on
image_path= "/mnt/data/andrea_bees/images/young-adults-white-blue-outside-97-128_batch_2_pass_2.mp4.track000194.frame034064.png"

#out_path="/home/lqmeyers/paintDetect/data/full_masks/f3.1x2022_06_22.mp4.track000093.frame007395.pred.jpg"


#initialize logging and run prediction--------

logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
model = '/home/lmeyers/paintDetect/Pytorch-UNet/1_classes_2026-07-14 15:44:32.338657.pth'

net = UNet(n_channels=3, n_classes=5, bilinear=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
logging.info(f'Loading model {model}')
logging.info(f'Using device {device}')


net = torch.load(model, map_location=device, weights_only=False)
net.to(device=device)
#mask_values = state_dict.pop('mask_values', [0, 1])
#net.load_state_dict(state_dict)

logging.info('Model loaded!')
logging.info(f'Predicting image {image_path} ...')

img = Image.open(image_path)
print("original image size: ", img.size)
#resize to 200 x 200
img = img.resize((200, 200))
# crop to 200 x 150 around center
img = img.crop(( 25,0, 175, 200))  # (left, upper, right, lower)

mask = predict_img(net=net,
                    full_img=img,
                    scale_factor=1,
                    out_threshold=.5,
                    device=device)


plt.imshow(mask)
plt.imshow(img,alpha=0.5) #overlay mask on image
plt.show()

# out_filename = out_path

#print(mask[55]) #array of class prediction
#result = mask_to_image(mask, mask_values)
# result.save(out_filename) #this is causing the problem!!!!!!!!!!!!!!!!!!!!!!!!!!!
# logging.info(f'Mask saved to {out_filename}')

# result = Image.open(out_filename)
# #--------visualize results-------------

# if  np.array(img).shape != np.array(result).shape:
#     arr = np.array(result)
#     arr_reshaped = np.expand_dims(arr, axis=-1)  # Add a new axis at the end
#     arr_reshaped = np.tile(arr_reshaped, (1, 1, 3)) 
#     if  np.array(img).shape != np.array(arr_reshaped).shape:
#         print('check input image dimensions, remember to put binary masks second')
#         pass
# # Stitch the images horizontally
#     stitched_image = np.concatenate((img, arr_reshaped), axis=1)
# else:
#     stitched_image = np.concatenate((img, result), axis=1)

# # Display the stitched image
# print("predicted results for ",image_path)

# plt.imshow(stitched_image)
# plt.axis('off')
# plt.show()
# Out:
# INFO: Loading model /home/lmeyers/paintDetect/Pytorch-UNet/1_classes_2026-07-14 15:44:32.338657.pth
# INFO: Using device cuda
# INFO: Model loaded!
# INFO: Predicting image /mnt/data/andrea_bees/images/young-adults-white-blue-outside-97-128_batch_2_pass_2.mp4.track000194.frame034064.png ...
# original image size:  (250, 250)

# %%
# get masked pixel values and display histograms of hue, saturation, and value
pixels = np.array(img)[mask==1] #get pixel values where mask is 1

#make into hsv
from matplotlib.colors import rgb_to_hsv
pixels_hsv = rgb_to_hsv(pixels/255.0) #convert to hsv

# OpenCV uses a 0-179 range for Hue to fit within an 8-bit integer
import cv2
hue_data = (pixels_hsv[:, 0] * 179).astype(int)
bins = 180
counts, bin_edges, patches = plt.hist(hue_data, bins=bins, range=(0, 180), edgecolor='none')

# 4. Color each individual bar based on its respective Hue value
for i, patch in enumerate(patches):
    # Calculate the center Hue value for the current bar
    hue_val = int((bin_edges[i] + bin_edges[i+1]) / 2)
    
    # Create a 1x1 pixel image in HSV format with maximum Saturation and Value
    hsv_pixel = np.uint8([[[hue_val, 255, 255]]])
    
    # Convert that pixel to RGB format to get the normalized [0, 1] color values for Matplotlib
    rgb_pixel = cv2.cvtColor(hsv_pixel, cv2.COLOR_HSV2RGB)[0][0] / 255.0
    
    # Dynamically apply the color to the bar patch
    patch.set_facecolor(rgb_pixel)

# 5. Format and display the plot
plt.title("Hue Histogram (Colored by Hue)")
plt.xlabel("Hue Value (0 - 179)")
plt.ylabel("Frequency")
plt.xlim(0, 180)
plt.show()
