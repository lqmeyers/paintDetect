# %%
##testing using pytorch to build model

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # use GPU with index 1

# %%
# !python ./Pytorch-UNet/train_and_eval.py --config_file ./Pytorch-UNet/UNet_segmentation_train_config.yml
# Out:
# beginning execution
# Using GPU 1
# number of batches of validation rounds is 2
# wandb: Currently logged in as: anony-moose-624569776008388248. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /home/lqmeyers/paintDetect/wandb/run-20231227_123353-t6zx5s5j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run trim-fog-72
# wandb: ⭐️ View project at https://wandb.ai/anony-moose-624569776008388248/U-Net?apiKey=a0d182f4897593f0e7ebd6731476179b00a41112
# wandb: 🚀 View run at https://wandb.ai/anony-moose-624569776008388248/U-Net/runs/t6zx5s5j?apiKey=a0d182f4897593f0e7ebd6731476179b00a41112
# wandb: WARNING Do NOT share these links with anyone. They can be used to claim your runs.
# ...
# Epoch 1/1: 100%|█████████| 130/130 [02:20<00:00,  1.08s/img, loss (batch)=0.287]
# saving file ./predict2023-12-27-12:36:21/f21x2022_06_28.mp4.track000004.frame00019.pred.conf_matr.npy
# ...

# %%
# !cp ./checkpoints/checkpoint_epoch30.pth /home/lmeyers/paintDetect/wandb/latest-run/files/model.pth
# Out:
# cp: cannot stat './checkpoints/checkpoint_epoch30.pth': No such file or directory
