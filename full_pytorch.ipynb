# %%
##testing using pytorch to build model

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU with index 1

# %%
# !python ./Pytorch-UNet/train.py -e 30 -b 10 -c 2 -v 15 -s 1 -l 1e-4
# Out:
# INFO: Using device cuda
# INFO: Network:
# 	3 input channels
# 	2 output channels (classes)
# 	Transposed conv upscaling
# INFO: Creating dataset with 197 examples
# INFO: Scanning mask files to determine unique values
#   0%|                                                   | 0/197 [00:00<?, ?it/s]
# INFO: Creating dataset with 197 examples
# INFO: Scanning mask files to determine unique values
# 100%|███████████████████████████████████████| 197/197 [00:00<00:00, 2012.75it/s]
# INFO: Unique mask values: [0, 255]
# number of batches of validation rounds is 2
# wandb: Currently logged in as: lqmeyers (meyers_luke_lab). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.1
# wandb: Run data is saved locally in /home/lmeyers/paintDetect/wandb/run-20230517_224404-8xbgtqw6
# wandb: Run `wandb offline` to turn off syncing.
# ...

# %%
# !cp ./checkpoints/checkpoint_epoch30.pth /home/lmeyers/paintDetect/wandb/latest-run/files/model.pth

# %%
#need to change model used first!!
# !bash predict_on_training.sh
